# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Iris.csv")

# %% [markdown]
# # Amostra Aleatória Simples

# %%
df.shape
# Out:
# (150, 6)

# %%
# Amostra aleatória Simples
amostra_simples = df.sample(30,replace=True)

# %%
amostra_simples.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 56    57            6.3           3.3            4.7           1.6
# 129  130            7.2           3.0            5.8           1.6
# 138  139            6.0           3.0            4.8           1.8
# 105  106            7.6           3.0            6.6           2.1
# 24    25            4.8           3.4            1.9           0.2
#
#              Species
# 56   Iris-versicolor
# 129   Iris-virginica
# 138   Iris-virginica
# 105   Iris-virginica
# 24       Iris-setosa

# %%
amostra_simples.shape
# Out:
# (30, 6)

# %% [markdown]
# # Amostra Sistemática

# %%
# Amostra aleatória Sistemática
def amostragem_sistemica(df, step):
  indexes = np.arange(3, len(df), step=step)
  amostra_sistematica = df.iloc[indexes]
  return amostra_sistematica

amostra_sistematica = amostragem_sistemica(df,3)

# %%
amostra_sistematica.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa

# %%
amostra_sistematica.shape
# Out:
# (49, 6)

# %% [markdown]
# # Amostra Estratificada

# %%
# Amostra aleatória de acordo com um subgrupo
df.groupby('Species',group_keys=False).apply(lambda x : x.sample(5))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 47    48            4.6           3.2            1.4           0.2
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 19    20            5.1           3.8            1.5           0.3
# 23    24            5.1           3.3            1.7           0.5
# 60    61            5.0           2.0            3.5           1.0
# 97    98            6.2           2.9            4.3           1.3
# 78    79            6.0           2.9            4.5           1.5
# 57    58            4.9           2.4            3.3           1.0
# 93    94            5.0           2.3            3.3           1.0
# 117  118            7.7           3.8            6.7           2.2
# 124  125            6.7           3.3            5.7           2.1
# 118  119            7.7           2.6            6.9           2.3
# ...

# %% [markdown]
# # Amostra Clusterizada

# %%
df01 = pd.read_csv("/content/Iris.csv")

# %%
def amostra_cluster(df, n_por_cluster, num_cluster):
  N = len(df)
  K = int(N/n_por_cluster)
  data = None
  for k in range(K):
    sample_k = df.sample(n_por_cluster)
    sample_k['cluster'] = np.repeat(k,len(sample_k))
    df = df.drop(index = sample_k.index)
    data = pd.concat([data, sample_k], axis=0)

    escolha_cluster_aleatorio = np.random.randint(0,K, size = num_cluster)
    samples = data[data.cluster.isin(escolha_cluster_aleatorio)]
    return(samples)

sample = amostra_cluster(df=df01,n_por_cluster=30,num_cluster=2)
sample
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 80    81            5.5           2.4            3.8           1.1
# 27    28            5.2           3.5            1.5           0.2
# 48    49            5.3           3.7            1.5           0.2
# 88    89            5.6           3.0            4.1           1.3
# 91    92            6.1           3.0            4.6           1.4
# 137  138            6.4           3.1            5.5           1.8
# 46    47            5.1           3.8            1.6           0.2
# 103  104            6.3           2.9            5.6           1.8
# 130  131            7.4           2.8            6.1           1.9
# 58    59            6.6           2.9            4.6           1.3
# 149  150            5.9           3.0            5.1           1.8
# 44    45            5.1           3.8            1.9           0.4
# 95    96            5.7           3.0            4.2           1.2
# ...
